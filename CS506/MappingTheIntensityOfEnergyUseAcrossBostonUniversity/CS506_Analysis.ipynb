# %% [markdown]
# # Data Analysis for CS506 Project
#
# In CS506_DataProcessing_Graph.ipynb file, datasets are processed and cleaned finally store in 2 csv files. Two files are: **df_201x_BU_analysis_E_Final.csv** and **df_201x_BU_analysis_G_Final.csv**. In this analysis, we directly use those two files to do the analysis

# %%
# Import files
import csv
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from statsmodels.formula.api import ols, logit

import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
# import statsmodels.formula.api as smf
# Out:
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# Read data
df_BU_analysis_E = pd.read_csv('df_201x_BU_analysis_E_Final.csv', index_col=0)
df_BU_analysis_G = pd.read_csv('df_201x_BU_analysis_G_Final.csv', index_col=0)

# Data for E and G
print(df_BU_analysis_G.columns)
print(df_BU_analysis_E.columns)
# Out:
# Index(['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports',
#        'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel',
#        'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical',
#        'Y_Gas', 'Y_Very_Low_G', 'Y_Low_G', 'Y_Medium_G', 'Y_High_G',
#        'Y_Very_High_G'],
#       dtype='object')
# Index(['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports',
#        'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel',
#        'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical',
#        'Y_Electric', 'Y_Very_Low_E', 'Y_Low_E', 'Y_Medium_E', 'Y_High_E',
#        'Y_Very_High_E'],
#       dtype='object')

# %%
# Browsing data for Electricity
# df_BU_analysis_E.head(10)

# %%
# Browsing data for Gas
# df_BU_analysis_G.head(10)

# %%
# Generating Training and Testing sets for 2 regressions (Electricity, Gas)
df_BU_analysis_E_shuffle = df_BU_analysis_E.sample(frac = 1)
df_BU_analysis_G_shuffle = df_BU_analysis_G.sample(frac = 1)

# num_e = int(len(df_BU_analysis_E_shuffle)*0.9)
# num_g = int(len(df_BU_analysis_G_shuffle)*0.9)

df_BU_training_E = df_BU_analysis_E_shuffle
df_BU_training_G = df_BU_analysis_G_shuffle

# df_BU_training_E = df_BU_analysis_E_shuffle.iloc[:num_e, :]
# df_BU_testing_E = df_BU_analysis_E_shuffle.iloc[num_e:, :]

# df_BU_training_G = df_BU_analysis_G_shuffle.iloc[:num_g, :]
# df_BU_testing_G = df_BU_analysis_G_shuffle.iloc[num_g:, :]

X_column = ['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports', 'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel', 'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical']
# X_column = ['Temperature', 'WI', 'Age', 'Uses_College', 'Uses_Sports', 'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel', 'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical']

# %%
def printVariables():
    for i in range(len(X_column)):
        print('x{}: {}'.format(i+1, X_column[i]))

# %% [markdown]
# ## Linear Regression

# %%
# Statesmodel Version of LR
# Traning Data

X_E = df_BU_training_E[X_column]
Y_E = df_BU_training_E['Y_Electric']

X_G = df_BU_training_G[X_column]
Y_G = df_BU_training_G['Y_Gas']


# Testing Data
# X_E_test = df_BU_testing_E[X_column]
# Y_E_test = df_BU_testing_E['Y_Electric']

# X_G_test = df_BU_testing_G[X_column]
# Y_G_test = df_BU_testing_G['Y_Gas']

print('BU_data shape')
print(df_BU_analysis_E.shape)
print(df_BU_analysis_G.shape)
print(df_BU_analysis_E_shuffle.shape)
print(df_BU_analysis_G_shuffle.shape)
print()
print('Training Data Shape:')
print(X_E.shape)
print(X_G.shape)
print()
print(Y_E.shape)
print(Y_G.shape)
print()
# print('Testing Data Shape:')
# print(X_E_test.shape)
# print(X_G_test.shape)
# print()
# print(Y_E_test.shape)
# print(Y_G_test.shape)
# Out:
# BU_data shape
# (1512, 20)
# (1404, 20)
# (1512, 20)
# (1404, 20)
#
# Training Data Shape:
# (1512, 14)
# (1404, 14)
#
# (1512,)
# (1404,)

# %%
# Run the regression:
version = 'statsModel'
# version = 'sklearn'


if version == 'statsModel':
    # Electricity
    # OLS regression
    model_e = ols(
    formula = 'Y_Electric ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E) 
    results_e = model_e.fit()
    
    # Gas
    # OLS regression 
    model_g = ols(
    formula = 'Y_Gas ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

    results_g = model_g.fit()
    
else:
    
    # Using Sklearn linear model to do the prediction
    linearModel_E = LinearRegression(fit_intercept=True, normalize = True)
    linearModel_G = LinearRegression(fit_intercept=True, normalize = True)


    linearModel_E.fit(X_E, Y_E)
    linearModel_G.fit(X_G, Y_G)

    # linear regression accuracy through cross validation
    score_E = cross_val_score(linearModel_E, X_E, Y_E, cv=3)
    score_linear_mean_E = score_E.mean()
    score_G = cross_val_score(linearModel_G, X_G, Y_G, cv=3)
    score_linear_mean_G = score_G.mean()



    np.set_printoptions(suppress=True)

    print('E: Parameters')
    print(linearModel_E.coef_.shape)
    print(linearModel_E.intercept_)

    print()
    print('G: Parameters')
    print(linearModel_G.coef_.shape)
    print(linearModel_G.intercept_)


    coef_E = linearModel_E.coef_
    coef_G = linearModel_G.coef_

    coef_E = coef_E.reshape(coef_E.shape[0], 1)
    coef_G = coef_G.reshape(coef_G.shape[0], 1)

    df_coef_E = pd.DataFrame(coef_E.T, columns = X_column)
    df_coef_G = pd.DataFrame(coef_G.T, columns = X_column)

    df_coef_E['Const'] = linearModel_E.intercept_
    df_coef_G['Const'] = linearModel_G.intercept_

# %%
if version == 'sklearn':
    df_coef_E
else:
    printVariables()
    print()
    print(results_e.summary())
# Out:
# x1: Temperature
# x2: WI
# x3: GHGI
# x4: Age
# x5: Uses_College
# x6: Uses_Sports
# x7: Uses_ResidentHousing
# x8: Uses_Laboratory
# x9: Uses_Office
# x10: Uses_Hotel
# x11: Uses_Distribution
# x12: Uses_Food
# x13: Uses_Worship
# x14: Uses_Medical
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Y_Electric   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     427.1
# Date:                Wed, 02 May 2018   Prob (F-statistic):               0.00
# Time:                        00:31:35   Log-Likelihood:                -2875.5
# No. Observations:                1512   AIC:                             5781.
# Df Residuals:                    1497   BIC:                             5861.
# Df Model:                          14
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              -48.4772      6.803     -7.126      0.000     -61.821     -35.134
# Temperature              0.0124      0.003      4.793      0.000       0.007       0.017
# WI                       0.0188      0.006      3.121      0.002       0.007       0.031
# GHGI                     3.7164      0.116     32.172      0.000       3.490       3.943
# Age                      0.0168      0.001     13.235      0.000       0.014       0.019
# Uses_College            16.4515      6.303      2.610      0.009       4.087      28.816
# Uses_Sports             16.3120      6.293      2.592      0.010       3.968      28.656
# Uses_ResidentHousing    14.9966      6.284      2.387      0.017       2.671      27.322
# Uses_Laboratory         19.8540      6.300      3.152      0.002       7.497      32.211
# Uses_Office             16.6858      6.304      2.647      0.008       4.321      29.051
# Uses_Hotel              16.4670      6.286      2.620      0.009       4.137      28.797
# Uses_Distribution       15.7083      6.315      2.487      0.013       3.321      28.095
# Uses_Food               17.0144      6.296      2.702      0.007       4.664      29.365
# Uses_Worship            14.7350      6.307      2.336      0.020       2.363      27.107
# Uses_Medical            18.1456      6.305      2.878      0.004       5.779      30.512
# ==============================================================================
# Omnibus:                      568.751   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4621.221
# Skew:                           1.532   Prob(JB):                         0.00
# Kurtosis:                      10.998   Cond. No.                     9.77e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
if version == 'sklearn':
    df_coef_G
else:
    printVariables()
    print()
    print(results_g.summary())
# Out:
# x1: Temperature
# x2: WI
# x3: GHGI
# x4: Age
# x5: Uses_College
# x6: Uses_Sports
# x7: Uses_ResidentHousing
# x8: Uses_Laboratory
# x9: Uses_Office
# x10: Uses_Hotel
# x11: Uses_Distribution
# x12: Uses_Food
# x13: Uses_Worship
# x14: Uses_Medical
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Y_Gas   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     243.9
# Date:                Wed, 02 May 2018   Prob (F-statistic):               0.00
# Time:                        00:31:35   Log-Likelihood:                -3870.4
# No. Observations:                1404   AIC:                             7769.
# Df Residuals:                    1390   BIC:                             7842.
# Df Model:                          13
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               54.2117      5.677      9.549      0.000      43.075      65.349
# Temperature             -0.1886      0.006    -29.946      0.000      -0.201      -0.176
# WI                      -0.3681      0.071     -5.207      0.000      -0.507      -0.229
# GHGI                    12.2962      0.300     40.987      0.000      11.708      12.885
# Age                     -0.0263      0.003     -8.261      0.000      -0.033      -0.020
# Uses_College             5.3644      0.552      9.720      0.000       4.282       6.447
# Uses_Sports              5.2673      0.743      7.088      0.000       3.809       6.725
# Uses_ResidentHousing     8.5701      0.624     13.727      0.000       7.345       9.795
# Uses_Laboratory          0.2582      0.623      0.414      0.679      -0.964       1.481
# Uses_Office              5.8195      0.566     10.278      0.000       4.709       6.930
# Uses_Hotel               6.1252      0.951      6.440      0.000       4.259       7.991
# Uses_Distribution        6.2934      0.896      7.022      0.000       4.535       8.052
# Uses_Food                4.6309      0.933      4.964      0.000       2.801       6.461
# Uses_Worship             7.6521      0.936      8.179      0.000       5.817       9.487
# Uses_Medical             4.2305      0.821      5.151      0.000       2.619       5.842
# ==============================================================================
# Omnibus:                      730.967   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11025.825
# Skew:                           2.059   Prob(JB):                         0.00
# Kurtosis:                      16.096   Cond. No.                     2.74e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.17e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# # Computing MSE
# np.set_printoptions(suppress=True)

# #predicted comments according to wights
# def to_pred(f_coef,f_data):
#     # feature dot product with weights
#     # feature f_data from testing group
#     # weight f_coef from training
#     # predicted comments 
#     constant = f_coef.loc[0,'Const']
#     f_coef.drop(['Const'], axis = 1, inplace= True)
#     f_coef = f_coef.T
#     pred = np.dot(f_data,f_coef)
#     pred = pred + constant
#     return pred


# if version == 'sklearn':
#     #prediction of testing group 
#     y_pred_E = to_pred(df_coef_E,X_E_test)
#     y_pred_G = to_pred(df_coef_G,X_G_test)


#     #true value of testing group
#     y_true_E = Y_E_test
#     y_true_G = Y_G_test

#     #mean squared error
#     print('---------------Mean Suared Error of Electric---------------')
#     print(mean_squared_error(y_true_E, y_pred_E))
#     print('---------------Mean Suared Error of Gas---------------')
#     print(mean_squared_error(y_true_G, y_pred_G))
    
# else:
    
#     # Electricity
#     print('Electricity:')
#     const_e = results_e.params[0]
#     params_e = results_e.params[1:]
#     params_e = np.reshape(params_e, (params_e.shape[0], 1))

#     print('Constant:')
#     print(const_e)
#     print()
#     print('Parameters:')
#     print(params_e)
#     print() 

#     # Y_test
#     Y_hat_e = np.dot(x_eTest, params_e) + const_e
#     print('MSE:')
#     print(mean_squared_error(y_eTest, Y_hat_e))
    
#     print()
#     print('------------------------------')
#     print()
    
#     # Gas
#     print('Gas:')
#     const_g = results_g.params[0]
#     params_g = results_g.params[1:]
#     params_g = np.reshape(params_g, (params_g.shape[0], 1))

#     print('Constant:')
#     print(const_g)
#     print()
#     print('Parameters:')
#     print(params_g)
#     print() 

#     # Y_test
#     Y_hat_g = np.dot(x_gTest, params_g) + const_g
#     print('MSE:')
#     print(mean_squared_error(y_gTest, Y_hat_g))

# %% [markdown]
# ## Cross Validation - Linear Regression Regularized (Fail, Performace worse)

# %%
# Cross validation score for statsmodel linear regression
# score = mse.mean()

def cross_validation(df, cv, label, regularize, a):
    #shuffle dataframe
    df = df.sample(frac = 1)
    lst_mse = []
    row_num = int(len(df))
    num = int(row_num / cv)
    n = 0
    while n < row_num:
        n_next = n + num
        # split data into training and testing 
        if n_next >= row_num:
            df_testing = df.iloc[n:, :]
            df_training = df.drop(df.index[[n,]],axis = 0)
        else:
            df_testing = df.iloc[n:n_next,:]
            df_training = df.drop(df.index[[n,n_next]], axis = 0)
        
        X_train = df_training.drop([label],axis = 1)
        Y_train = df_training[label]
        X_test = df_testing.drop([label],axis = 1)
        Y_test = df_testing[label]
        mod = sm.OLS(Y_train,X_train)
        res = mod.fit()
        if regularize == True:
            res_reg = mod.fit_regularized(alpha = a, L1_wt = 0, start_params = res.params)
            Y_pred = res_reg.predict(X_test)
        else:
            Y_pred = res.predict(X_test)
        mse = mean_squared_error(Y_test, Y_pred)
        lst_mse.append(mse)
        n = n_next
        m_mse = np.mean(lst_mse)
    return m_mse

# %%
score_E = cross_validation(df_BU_analysis_E, 5, 'Y_Electric', False, 0)
score_G = cross_validation(df_BU_analysis_G, 5, 'Y_Gas', False, 0)
print('Score of linear model on electricity is ', score_E)
print('Score of linear model on gas is ', score_G)

print('-------------------------------------------')

score_E_reg = cross_validation(df_BU_analysis_E, 5, 'Y_Electric', True, 0)
score_G_reg = cross_validation(df_BU_analysis_G, 5, 'Y_Gas', True, 0)
print('Score of regularized linear model on electricity is ', score_E_reg)
print('Score of regularized linear model on gas is ', score_G_reg)
# Out:
# Score of linear model on electricity is  1.0729929794
# Score of linear model on gas is  3.91172189048
# -------------------------------------------
# Score of regularized linear model on electricity is  1.20188001771
# Score of regularized linear model on gas is  3.77547938064

# %% [markdown]
# ## Non-Linear Model (Quadratic term)

# %%
print(df_BU_training_E.columns)
print() 
print(df_BU_training_G.columns)
# Out:
# Index(['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports',
#        'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel',
#        'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical',
#        'Y_Electric', 'Y_Very_Low_E', 'Y_Low_E', 'Y_Medium_E', 'Y_High_E',
#        'Y_Very_High_E'],
#       dtype='object')
#
# Index(['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports',
#        'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel',
#        'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical',
#        'Y_Gas', 'Y_Very_Low_G', 'Y_Low_G', 'Y_Medium_G', 'Y_High_G',
#        'Y_Very_High_G'],
#       dtype='object')

# %%
# df_BU_training_E = df_BU_analysis_E_shuffle.iloc[:num_e, :]
# df_BU_testing_E = df_BU_analysis_E_shuffle.iloc[num_e:, :]

# df_BU_training_G = df_BU_analysis_G_shuffle.iloc[:num_g, :]
# df_BU_testing_G = df_BU_analysis_G_shuffle.iloc[num_g:, :]

# X_column = ['Temperature', 'WI', 'GHGI', 'Age', 'Uses_College', 'Uses_Sports', 'Uses_ResidentHousing', 'Uses_Laboratory', 'Uses_Office', 'Uses_Hotel', 'Uses_Distribution', 'Uses_Food', 'Uses_Worship', 'Uses_Medical']


# Electricity

# quadratic OLS regression
model_e_q = ols(
    formula = 'Y_Electric ~ np.power(Temperature, 2) + WI + np.power(GHGI, 2) + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E) 

results_e_q = model_e_q.fit()

# np.power(GHGI, 2)

# Gas

# quadratic OLS regression 

model_g_q = ols(
    formula = 'Y_Gas ~ np.power(Temperature, 2) + WI + np.power(GHGI, 2) + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_g_q = model_g_q.fit()

# %%
printVariables()
print()
print(results_e_q.summary())
# Out:
# x1: Temperature
# x2: WI
# x3: GHGI
# x4: Age
# x5: Uses_College
# x6: Uses_Sports
# x7: Uses_ResidentHousing
# x8: Uses_Laboratory
# x9: Uses_Office
# x10: Uses_Hotel
# x11: Uses_Distribution
# x12: Uses_Food
# x13: Uses_Worship
# x14: Uses_Medical
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Y_Electric   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     361.2
# Date:                Wed, 02 May 2018   Prob (F-statistic):               0.00
# Time:                        00:31:35   Log-Likelihood:                -2975.1
# No. Observations:                1512   AIC:                             5980.
# Df Residuals:                    1497   BIC:                             6060.
# Df Model:                          14
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  -51.9007      7.269     -7.140      0.000     -66.160     -37.642
# np.power(Temperature, 2)     0.0001   2.67e-05      5.423      0.000    9.24e-05       0.000
# WI                           0.0223      0.006      3.465      0.001       0.010       0.035
# np.power(GHGI, 2)            1.3777      0.052     26.711      0.000       1.277       1.479
# Age                          0.0177      0.001     13.056      0.000       0.015       0.020
# Uses_College                20.0090      6.731      2.973      0.003       6.806      33.212
# Uses_Sports                 19.7494      6.720      2.939      0.003       6.567      32.932
# Uses_ResidentHousing        18.3405      6.711      2.733      0.006       5.177      31.504
# Uses_Laboratory             23.8279      6.725      3.543      0.000      10.636      37.020
# Uses_Office                 20.1383      6.732      2.992      0.003       6.934      33.343
# Uses_Hotel                  20.1664      6.712      3.004      0.003       7.000      33.333
# Uses_Distribution           19.5448      6.743      2.899      0.004       6.319      32.771
# Uses_Food                   21.1367      6.722      3.144      0.002       7.951      34.322
# Uses_Worship                17.1335      6.738      2.543      0.011       3.917      30.350
# Uses_Medical                22.3530      6.730      3.321      0.001       9.151      35.555
# ==============================================================================
# Omnibus:                      490.469   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3152.185
# Skew:                           1.356   Prob(JB):                         0.00
# Kurtosis:                       9.533   Cond. No.                     1.93e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
printVariables()
print()
print(results_g_q.summary())
# Out:
# x1: Temperature
# x2: WI
# x3: GHGI
# x4: Age
# x5: Uses_College
# x6: Uses_Sports
# x7: Uses_ResidentHousing
# x8: Uses_Laboratory
# x9: Uses_Office
# x10: Uses_Hotel
# x11: Uses_Distribution
# x12: Uses_Food
# x13: Uses_Worship
# x14: Uses_Medical
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Y_Gas   R-squared:                       0.649
# Model:                            OLS   Adj. R-squared:                  0.646
# Method:                 Least Squares   F-statistic:                     197.9
# Date:                Wed, 02 May 2018   Prob (F-statistic):          8.50e-305
# Time:                        00:31:35   Log-Likelihood:                -3969.0
# No. Observations:                1404   AIC:                             7966.
# Df Residuals:                    1390   BIC:                             8039.
# Df Model:                          13
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   57.3827      6.144      9.339      0.000      45.329      69.436
# np.power(Temperature, 2)    -0.0018   6.54e-05    -27.257      0.000      -0.002      -0.002
# WI                          -0.2035      0.075     -2.717      0.007      -0.350      -0.057
# np.power(GHGI, 2)            4.7240      0.130     36.354      0.000       4.469       4.979
# Age                         -0.0276      0.003     -8.041      0.000      -0.034      -0.021
# Uses_College                 5.4003      0.596      9.063      0.000       4.231       6.569
# Uses_Sports                  6.2002      0.806      7.692      0.000       4.619       7.781
# Uses_ResidentHousing         7.6597      0.670     11.441      0.000       6.346       8.973
# Uses_Laboratory              1.1189      0.664      1.686      0.092      -0.183       2.421
# Uses_Office                  5.4406      0.607      8.960      0.000       4.250       6.632
# Uses_Hotel                   6.5013      1.029      6.318      0.000       4.483       8.520
# Uses_Distribution            7.5101      0.967      7.763      0.000       5.612       9.408
# Uses_Food                    6.5637      1.012      6.486      0.000       4.578       8.549
# Uses_Worship                 4.4516      0.986      4.515      0.000       2.517       6.386
# Uses_Medical                 6.5365      0.882      7.412      0.000       4.806       8.266
# ==============================================================================
# Omnibus:                      643.886   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7374.175
# Skew:                           1.827   Prob(JB):                         0.00
# Kurtosis:                      13.616   Cond. No.                     5.04e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Cross Validation - Quadratic Nonlinear Regression

# %%
# Cross validation score for quadratic linear regression
# score = mse.mean()

def cross_validation_q(df, cv, label, regularize, a):
    #shuffle dataframe
    df = df.sample(frac = 1)
    lst_mse = []
    row_num = int(len(df))
    num = int(row_num / cv)
    n = 0
    while n < row_num:
        n_next = n + num
        # split data into training and testing 
        if n_next >= row_num:
            df_testing = df.iloc[n:, :]
            df_training = df.drop(df.index[[n,]],axis = 0)
        else:
            df_testing = df.iloc[n:n_next,:]
            df_training = df.drop(df.index[[n,n_next]], axis = 0)
        X_test = df_testing.drop([label],axis = 1)
        Y_test = df_testing[label]
        mod = ols(formula = label +'~ Temperature + WI + np.power(GHGI, 2)+ Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
                        data = df_training) 
        res = mod.fit()
        if regularize == True:
            res_reg = mod.fit_regularized(alpha = a, L1_wt = 0, start_params = res.params)
            Y_pred = res_reg.predict(X_test)
        else:
            Y_pred = res.predict(X_test)
        mse = mean_squared_error(Y_test, Y_pred)
        lst_mse.append(mse)
        n = n_next
        m_mse = np.mean(lst_mse)
    return m_mse

# %%
df_test_E = df_BU_analysis_E.copy()
df_test_G = df_BU_analysis_G.copy()

print(df_test_E.columns.values)
print(df_test_G.columns.values)
# Out:
# ['Temperature' 'WI' 'GHGI' 'Age' 'Uses_College' 'Uses_Sports'
#  'Uses_ResidentHousing' 'Uses_Laboratory' 'Uses_Office' 'Uses_Hotel'
#  'Uses_Distribution' 'Uses_Food' 'Uses_Worship' 'Uses_Medical' 'Y_Electric'
#  'Y_Very_Low_E' 'Y_Low_E' 'Y_Medium_E' 'Y_High_E' 'Y_Very_High_E']
# ['Temperature' 'WI' 'GHGI' 'Age' 'Uses_College' 'Uses_Sports'
#  'Uses_ResidentHousing' 'Uses_Laboratory' 'Uses_Office' 'Uses_Hotel'
#  'Uses_Distribution' 'Uses_Food' 'Uses_Worship' 'Uses_Medical' 'Y_Gas'
#  'Y_Very_Low_G' 'Y_Low_G' 'Y_Medium_G' 'Y_High_G' 'Y_Very_High_G']

# %%
# Cross Validation

df_test_E['WI Quadratic'] = df_test_E['WI'] * df_test_E['WI']
df_test_G['WI Quadratic'] = df_test_G['WI'] * df_test_G['WI']
df_test_E['GHGI Quadratic'] = df_test_E['GHGI'] * df_test_E['GHGI']
df_test_G['GHGI Quadratic'] = df_test_G['GHGI'] * df_test_G['GHGI']


score_E_q = cross_validation(df_test_E, 5, 'Y_Electric', False, 0)
score_G_q = cross_validation(df_test_G, 5, 'Y_Gas', False, 0)
print('Score of quadraitc nonlinear model on electricity is ', score_E_q)
print('Score of quadratic nonlinear model on gas is ', score_G_q)

print('-------------------------------------------')

score_E_q_reg = cross_validation(df_test_E, 5, 'Y_Electric', True, 0)
score_G_q_reg = cross_validation(df_test_G, 5, 'Y_Gas', True, 0)
print('Score of regularized quadratic nonlinear model on electricity is ', score_E_q_reg)
print('Score of regularized quadratic nonlinear model on gas is ', score_G_q_reg)
# Out:
# Score of quadraitc nonlinear model on electricity is  0.849153391951
# Score of quadratic nonlinear model on gas is  3.15428269032
# -------------------------------------------
# Score of regularized quadratic nonlinear model on electricity is  0.816502872695
# Score of regularized quadratic nonlinear model on gas is  3.0926318138

# %% [markdown]
# ## Multi-class Logistic Regression

# %%
# Electricity

# 1. Logistic Regression
# Y_Very_Low_E
model_log_e_vlow = logit(
    formula = 'Y_Very_Low_E ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E)

results_log_e_vlow = model_log_e_vlow.fit(method='bfgs')

#----------------------

# 2. Logistic Regression
# Y_Low_E
model_log_e_low = logit(
    formula = 'Y_Low_E ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E)

results_log_e_low = model_log_e_low.fit(method='bfgs')
#----------------------

# 3. Logistic Regression
# Y_Medium_E
model_log_e_med = logit(
    formula = 'Y_Medium_E ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E)

results_log_e_med = model_log_e_med.fit(method='bfgs')

#----------------------

# 4. Logistic Regression
# Y_High_E
model_log_e_high = logit(
    formula = 'Y_High_E ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E)

results_log_e_high = model_log_e_high.fit(method='bfgs')

#----------------------

# 5. Logistic Regression
# Y_Very_High_E
model_log_e_vhigh = logit(
    formula = 'Y_Very_High_E ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_E)

results_log_e_vhigh = model_log_e_vhigh.fit(method='bfgs')
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.176845
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 45
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.380456
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.129939
#          Iterations: 35
#          Function evaluations: 64
#          Gradient evaluations: 57
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.044685
#          Iterations: 35
#          Function evaluations: 77
#          Gradient evaluations: 67
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.010210
#          Iterations: 35
#          Function evaluations: 82
#          Gradient evaluations: 79
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
# Gas

# 1. Logistic Regression
# Y_Very_Low_G
model_log_g_vlow = logit(
    formula = 'Y_Very_Low_G ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_log_g_vlow = model_log_g_vlow.fit(method='bfgs')

#----------------------

# 2. Logistic Regression
# Y_Low_G
model_log_g_med = logit(
    formula = 'Y_Medium_G ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_log_g_low = model_log_g_med.fit(method='bfgs')

#----------------------

# 3. Logistic Regression
# Y_Medium_G
model_log_g_med = logit(
    formula = 'Y_Medium_G ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_log_g_med = model_log_g_med.fit(method='bfgs')

#----------------------

# 4. Logistic Regression
# Y_High_G
model_log_g_high = logit(
    formula = 'Y_High_G ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_log_g_high = model_log_g_high.fit(method='bfgs')

#----------------------

# 5. Logistic Regression
# Y_Very_High_G
model_log_g_vhigh = logit(
    formula = 'Y_Very_High_G ~ Temperature + WI + GHGI + Age + Uses_College + Uses_Sports + Uses_ResidentHousing + Uses_Laboratory + Uses_Office + Uses_Hotel + Uses_Distribution + Uses_Food + Uses_Worship + Uses_Medical', 
    data = df_BU_training_G)

results_log_g_vhigh = model_log_g_vhigh.fit(method='bfgs')
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.185820
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.066756
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.066756
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.019113
#          Iterations: 35
#          Function evaluations: 59
#          Gradient evaluations: 55
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.004993
#          Iterations: 35
#          Function evaluations: 69
#          Gradient evaluations: 65
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/chengyudeng/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# ### Electricity Result

# %%
print(results_log_e_vlow.summary2())
# Out:
#                             Results: Logit
# ======================================================================
# Model:                 Logit              Pseudo R-squared:   0.721
# Dependent Variable:    Y_Very_Low_E       AIC:                564.7787
# Date:                  2018-05-02 00:31   BIC:                644.5966
# No. Observations:      1512               Log-Likelihood:     -267.39
# Df Model:              14                 LL-Null:            -957.48
# Df Residuals:          1497               Scale:              1.0000
# Converged:             0.0000
# ----------------------------------------------------------------------
#                       Coef.  Std.Err.    z     P>|z|   [0.025   0.975]
# ----------------------------------------------------------------------
# Intercept             0.6736  19.4735   0.0346 0.9724 -37.4938 38.8410
# Temperature          -0.0200   0.0070  -2.8571 0.0043  -0.0337 -0.0063
# WI                   -0.0038   0.0179  -0.2133 0.8311  -0.0390  0.0313
# GHGI                 -8.5171   0.6865 -12.4061 0.0000  -9.8626 -7.1715
# Age                   0.0036   0.0035   1.0257 0.3050  -0.0033  0.0104
# Uses_College          1.4436  18.1936   0.0793 0.9368 -34.2153 37.1025
# Uses_Sports           0.3861  18.1774   0.0212 0.9831 -35.2411 36.0132
# Uses_ResidentHousing  2.2963  18.1281   0.1267 0.8992 -33.2341 37.8266
# Uses_Laboratory      -3.8905  18.2838  -0.2128 0.8315 -39.7261 31.9451
# Uses_Office          -0.5412  18.1856  -0.0298 0.9763 -36.1844 35.1020
# Uses_Hotel           -0.3133  18.1261  -0.0173 0.9862 -35.8398 35.2133
# Uses_Distribution     2.5143  18.2242   0.1380 0.8903 -33.2045 38.2330
# Uses_Food            -2.1415  18.1854  -0.1178 0.9063 -37.7841 33.5012
# Uses_Worship          0.4388  18.4397   0.0238 0.9810 -35.7023 36.5799
# Uses_Medical          0.4641  18.1733   0.0255 0.9796 -35.1550 36.0831
# ======================================================================

# %%
print(results_log_e_low.summary2())
# Out:
#                            Results: Logit
# =====================================================================
# Model:                 Logit             Pseudo R-squared:  0.314
# Dependent Variable:    Y_Low_E           AIC:               1180.4996
# Date:                  2018-05-02 00:31  BIC:               1260.3174
# No. Observations:      1512              Log-Likelihood:    -575.25
# Df Model:              14                LL-Null:           -839.09
# Df Residuals:          1497              Scale:             1.0000
# Converged:             0.0000
# ---------------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z|   [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept            -0.1345  15.5256 -0.0087 0.9931 -30.5641 30.2952
# Temperature           0.0042   0.0046  0.9216 0.3567  -0.0047  0.0131
# WI                    0.0033   0.0142  0.2296 0.8184  -0.0245  0.0310
# GHGI                  1.5026   0.1775  8.4636 0.0000   1.1547  1.8506
# Age                  -0.0010   0.0023 -0.4567 0.6479  -0.0055  0.0034
# Uses_College         -0.9619  14.5578 -0.0661 0.9473 -29.4947 27.5709
# Uses_Sports          -0.2544  14.5182 -0.0175 0.9860 -28.7095 28.2006
# Uses_ResidentHousing -2.4629  14.5086 -0.1698 0.8652 -30.8992 25.9735
# Uses_Laboratory      -0.5816  14.5442 -0.0400 0.9681 -29.0876 27.9245
# Uses_Office           0.4601  14.5531  0.0316 0.9748 -28.0635 28.9837
# Uses_Hotel            0.8494  14.4972  0.0586 0.9533 -27.5646 29.2634
# Uses_Distribution    -1.2254  14.5749 -0.0841 0.9330 -29.7917 27.3410
# Uses_Food             3.2541  14.5338  0.2239 0.8228 -25.2316 31.7399
# Uses_Worship         -0.8850  14.5564 -0.0608 0.9515 -29.4150 27.6450
# Uses_Medical          1.6633  14.5478  0.1143 0.9090 -26.8499 30.1765
# =====================================================================

# %%
print(results_log_e_med.summary2())
# Out:
#                             Results: Logit
# =======================================================================
# Model:                  Logit              Pseudo R-squared:   0.474
# Dependent Variable:     Y_Medium_E         AIC:                422.9352
# Date:                   2018-05-02 00:31   BIC:                502.7530
# No. Observations:       1512               Log-Likelihood:     -196.47
# Df Model:               14                 LL-Null:            -373.49
# Df Residuals:           1497               Scale:              1.0000
# Converged:              0.0000
# -----------------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z|    [0.025   0.975]
# -----------------------------------------------------------------------
# Intercept            -0.1019  53.9900 -0.0019 0.9985 -105.9203 105.7165
# Temperature           0.0122   0.0081  1.4932 0.1354   -0.0038   0.0281
# WI                   -0.0009   0.0461 -0.0198 0.9842   -0.0914   0.0895
# GHGI                  2.5005   0.3695  6.7671 0.0000    1.7762   3.2247
# Age                  -0.0035   0.0053 -0.6528 0.5139   -0.0139   0.0070
# Uses_College         -1.1235  48.8666 -0.0230 0.9817  -96.9003  94.6533
# Uses_Sports           1.7411  48.4834  0.0359 0.9714  -93.2847  96.7669
# Uses_ResidentHousing -0.9657  48.5493 -0.0199 0.9841  -96.1205  94.1891
# Uses_Laboratory       1.7471  48.7398  0.0358 0.9714  -93.7811  97.2753
# Uses_Office          -0.9959  48.8908 -0.0204 0.9837  -96.8200  94.8283
# Uses_Hotel           -0.1482  48.4414 -0.0031 0.9976  -95.0915  94.7951
# Uses_Distribution    -0.1320  48.7590 -0.0027 0.9978  -95.6978  95.4339
# Uses_Food            -0.0267  48.5159 -0.0006 0.9996  -95.1161  95.0626
# Uses_Worship         -0.0925  48.6426 -0.0019 0.9985  -95.4302  95.2452
# Uses_Medical         -0.0878  48.7714 -0.0018 0.9986  -95.6780  95.5024
# =======================================================================

# %%
print(results_log_e_high.summary2())
# Out:
#                             Results: Logit
# =======================================================================
# Model:                  Logit              Pseudo R-squared:   0.452
# Dependent Variable:     Y_High_E           AIC:                165.1286
# Date:                   2018-05-02 00:31   BIC:                244.9465
# No. Observations:       1512               Log-Likelihood:     -67.564
# Df Model:               14                 LL-Null:            -123.24
# Df Residuals:           1497               Scale:              1.0000
# Converged:              0.0000
# -----------------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z|    [0.025   0.975]
# -----------------------------------------------------------------------
# Intercept            -0.0380  92.9981 -0.0004 0.9997 -182.3108 182.2349
# Temperature           0.0146   0.0145  1.0074 0.3137   -0.0138   0.0430
# WI                    0.0010   0.0776  0.0126 0.9899   -0.1511   0.1530
# GHGI                  2.9255   0.8536  3.4274 0.0006    1.2526   4.5984
# Age                  -0.0052   0.0124 -0.4193 0.6750   -0.0296   0.0192
# Uses_College         -0.8258  83.2366 -0.0099 0.9921 -163.9666 162.3149
# Uses_Sports          -0.4110  82.4468 -0.0050 0.9960 -162.0037 161.1817
# Uses_ResidentHousing -0.4137  82.7296 -0.0050 0.9960 -162.5607 161.7333
# Uses_Laboratory       2.2704  82.9248  0.0274 0.9782 -160.2593 164.8000
# Uses_Office          -0.5169  83.1804 -0.0062 0.9950 -163.5474 162.5137
# Uses_Hotel           -0.0396  82.7772 -0.0005 0.9996 -162.2800 162.2008
# Uses_Distribution    -0.0799  83.3486 -0.0010 0.9992 -163.4402 163.2804
# Uses_Food            -0.0551  82.7441 -0.0007 0.9995 -162.2306 162.1203
# Uses_Worship         -0.0853  84.4965 -0.0010 0.9992 -165.6954 165.5248
# Uses_Medical          0.1276  83.1109  0.0015 0.9988 -162.7667 163.0219
# =======================================================================

# %%
print(results_log_e_vhigh.summary2())
# Out:
#                             Results: Logit
# =======================================================================
# Model:                  Logit              Pseudo R-squared:   0.287
# Dependent Variable:     Y_Very_High_E      AIC:                60.8753
# Date:                   2018-05-02 00:31   BIC:                140.6932
# No. Observations:       1512               Log-Likelihood:     -15.438
# Df Model:               14                 LL-Null:            -21.665
# Df Residuals:           1497               Scale:              1.0000
# Converged:              0.0000
# -----------------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z|    [0.025   0.975]
# -----------------------------------------------------------------------
# Intercept            -0.0289 191.8007 -0.0002 0.9999 -375.9514 375.8936
# Temperature           0.0050   0.0365  0.1379 0.8903   -0.0665   0.0765
# WI                    0.0013   0.1586  0.0082 0.9934   -0.3096   0.3122
# GHGI                  2.4103   2.1460  1.1232 0.2614   -1.7957   6.6163
# Age                  -0.0056   0.0319 -0.1772 0.8593   -0.0681   0.0568
# Uses_College         -0.7678 168.6542 -0.0046 0.9964 -331.3240 329.7883
# Uses_Sports          -0.3919 167.2421 -0.0023 0.9981 -328.1803 327.3966
# Uses_ResidentHousing -0.4304 167.7041 -0.0026 0.9980 -329.1243 328.2635
# Uses_Laboratory       2.3227 168.0982  0.0138 0.9890 -327.1437 331.7890
# Uses_Office          -0.4322 168.6145 -0.0026 0.9980 -330.9106 330.0462
# Uses_Hotel           -0.0390 168.0603 -0.0002 0.9998 -329.4310 329.3531
# Uses_Distribution    -0.0747 169.2322 -0.0004 0.9996 -331.7637 331.6142
# Uses_Food            -0.0501 167.9205 -0.0003 0.9998 -329.1683 329.0682
# Uses_Worship         -0.0837 171.4193 -0.0005 0.9996 -336.0594 335.8919
# Uses_Medical         -0.0731 168.6040 -0.0004 0.9997 -330.5309 330.3846
# =======================================================================

# %% [markdown]
# ### Gas Result

# %%
print(results_log_g_vlow.summary2())
# Out:
#                               Results: Logit
# ===========================================================================
# Model:                  Logit                Pseudo R-squared:     0.580
# Dependent Variable:     Y_Very_Low_G         AIC:                  549.7833
# Date:                   2018-05-02 00:31     BIC:                  623.2424
# No. Observations:       1404                 Log-Likelihood:       -260.89
# Df Model:               13                   LL-Null:              -621.20
# Df Residuals:           1390                 Scale:                1.0000
# Converged:              0.0000
# ---------------------------------------------------------------------------
#                       Coef.   Std.Err.    z     P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept            -0.4854 2940.0830  -0.0002 0.9999 -5762.9422 5761.9714
# Temperature           0.1444    0.0120  12.0720 0.0000     0.1210    0.1679
# WI                    0.0325    0.0762   0.4267 0.6696    -0.1168    0.1819
# GHGI                 -6.2868    0.4945 -12.7124 0.0000    -7.2561   -5.3175
# Age                   0.0010    0.0036   0.2754 0.7830    -0.0060    0.0080
# Uses_College         -0.7927 2940.0911  -0.0003 0.9998 -5763.2655 5761.6800
# Uses_Sports           1.0120 2940.0918   0.0003 0.9997 -5761.4620 5763.4860
# Uses_ResidentHousing -1.7717 2940.0914  -0.0006 0.9995 -5764.2450 5760.7015
# Uses_Laboratory       2.4972 2940.0915   0.0008 0.9993 -5759.9761 5764.9706
# Uses_Office          -0.7645 2940.0912  -0.0003 0.9998 -5763.2374 5761.7084
# Uses_Hotel            0.8263 2940.0920   0.0003 0.9998 -5761.6482 5763.3007
# Uses_Distribution    -1.7255 2940.0913  -0.0006 0.9995 -5764.1986 5760.7477
# Uses_Food             1.2896 2940.0919   0.0004 0.9997 -5761.1847 5763.7639
# Uses_Worship          0.3648 2940.0940   0.0001 0.9999 -5762.1136 5762.8432
# Uses_Medical         -1.4209 2940.0910  -0.0005 0.9996 -5763.8933 5761.0516
# ===========================================================================

# %%
print(results_log_g_low.summary2())
# Out:
#                                Results: Logit
# ============================================================================
# Model:                   Logit                Pseudo R-squared:     0.463
# Dependent Variable:      Y_Medium_G           AIC:                  215.4518
# Date:                    2018-05-02 00:31     BIC:                  288.9110
# No. Observations:        1404                 Log-Likelihood:       -93.726
# Df Model:                13                   LL-Null:              -174.64
# Df Residuals:            1390                 Scale:                1.0000
# Converged:               0.0000
# ----------------------------------------------------------------------------
#                       Coef.   Std.Err.    z    P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept             0.0986 7242.9098  0.0000 1.0000 -14195.7438 14195.9410
# Temperature          -0.1039    0.0179 -5.8029 0.0000     -0.1390    -0.0688
# WI                    0.1001    0.1375  0.7279 0.4667     -0.1694     0.3695
# GHGI                  3.9539    0.5675  6.9672 0.0000      2.8416     5.0662
# Age                  -0.0024    0.0095 -0.2523 0.8008     -0.0211     0.0163
# Uses_College          1.5727 7242.9331  0.0002 0.9998 -14194.3153 14197.4607
# Uses_Sports           0.1284 7242.9353  0.0000 1.0000 -14195.7640 14196.0208
# Uses_ResidentHousing  0.7780 7242.9341  0.0001 0.9999 -14195.1120 14196.6680
# Uses_Laboratory      -1.1483 7242.9347 -0.0002 0.9999 -14197.0395 14194.7429
# Uses_Office          -0.3604 7242.9344 -0.0000 1.0000 -14196.2509 14195.5301
# Uses_Hotel           -0.2229 7242.9360 -0.0000 1.0000 -14196.1166 14195.6709
# Uses_Distribution    -0.0989 7242.9352 -0.0000 1.0000 -14195.9911 14195.7932
# Uses_Food            -0.2849 7242.9358 -0.0000 1.0000 -14196.1782 14195.6084
# Uses_Worship         -0.0876 7242.9425 -0.0000 1.0000 -14195.9941 14195.8189
# Uses_Medical         -0.1774 7242.9333 -0.0000 1.0000 -14196.0658 14195.7109
# ============================================================================

# %%
print(results_log_g_med.summary2())
# Out:
#                                Results: Logit
# ============================================================================
# Model:                   Logit                Pseudo R-squared:     0.463
# Dependent Variable:      Y_Medium_G           AIC:                  215.4518
# Date:                    2018-05-02 00:31     BIC:                  288.9110
# No. Observations:        1404                 Log-Likelihood:       -93.726
# Df Model:                13                   LL-Null:              -174.64
# Df Residuals:            1390                 Scale:                1.0000
# Converged:               0.0000
# ----------------------------------------------------------------------------
#                       Coef.   Std.Err.    z    P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept             0.0986 7242.9098  0.0000 1.0000 -14195.7438 14195.9410
# Temperature          -0.1039    0.0179 -5.8029 0.0000     -0.1390    -0.0688
# WI                    0.1001    0.1375  0.7279 0.4667     -0.1694     0.3695
# GHGI                  3.9539    0.5675  6.9672 0.0000      2.8416     5.0662
# Age                  -0.0024    0.0095 -0.2523 0.8008     -0.0211     0.0163
# Uses_College          1.5727 7242.9331  0.0002 0.9998 -14194.3153 14197.4607
# Uses_Sports           0.1284 7242.9353  0.0000 1.0000 -14195.7640 14196.0208
# Uses_ResidentHousing  0.7780 7242.9341  0.0001 0.9999 -14195.1120 14196.6680
# Uses_Laboratory      -1.1483 7242.9347 -0.0002 0.9999 -14197.0395 14194.7429
# Uses_Office          -0.3604 7242.9344 -0.0000 1.0000 -14196.2509 14195.5301
# Uses_Hotel           -0.2229 7242.9360 -0.0000 1.0000 -14196.1166 14195.6709
# Uses_Distribution    -0.0989 7242.9352 -0.0000 1.0000 -14195.9911 14195.7932
# Uses_Food            -0.2849 7242.9358 -0.0000 1.0000 -14196.1782 14195.6084
# Uses_Worship         -0.0876 7242.9425 -0.0000 1.0000 -14195.9941 14195.8189
# Uses_Medical         -0.1774 7242.9333 -0.0000 1.0000 -14196.0658 14195.7109
# ============================================================================

# %%
print(results_log_g_high.summary2())
# Out:
#                                Results: Logit
# =============================================================================
# Model:                    Logit                Pseudo R-squared:     0.507
# Dependent Variable:       Y_High_G             AIC:                  81.6706
# Date:                     2018-05-02 00:31     BIC:                  155.1297
# No. Observations:         1404                 Log-Likelihood:       -26.835
# Df Model:                 13                   LL-Null:              -54.420
# Df Residuals:             1390                 Scale:                1.0000
# Converged:                0.0000
# -----------------------------------------------------------------------------
#                       Coef.   Std.Err.     z    P>|z|     [0.025     0.975]
# -----------------------------------------------------------------------------
# Intercept            -0.0284 38371.6159 -0.0000 1.0000 -75207.0137 75206.9569
# Temperature          -0.1015     0.0363 -2.7980 0.0051     -0.1725    -0.0304
# WI                   -0.0709     0.3645 -0.1945 0.8458     -0.7853     0.6436
# GHGI                  3.4398     1.3565  2.5357 0.0112      0.7810     6.0986
# Age                  -0.0030     0.0284 -0.1072 0.9146     -0.0588     0.0527
# Uses_College         -1.0111 38371.6533 -0.0000 1.0000 -75208.0697 75206.0474
# Uses_Sports          -0.4194 38371.6574 -0.0000 1.0000 -75207.4860 75206.6471
# Uses_ResidentHousing  0.1362 38371.6562  0.0000 1.0000 -75206.9280 75207.2005
# Uses_Laboratory      -0.0982 38371.6556 -0.0000 1.0000 -75207.1612 75206.9647
# Uses_Office           1.7788 38371.6548  0.0000 1.0000 -75205.2827 75208.8403
# Uses_Hotel           -0.0471 38371.6595 -0.0000 1.0000 -75207.1177 75207.0234
# Uses_Distribution    -0.0878 38371.6571 -0.0000 1.0000 -75207.1537 75206.9780
# Uses_Food            -0.0785 38371.6586 -0.0000 1.0000 -75207.1474 75206.9904
# Uses_Worship         -0.1125 38371.6647 -0.0000 1.0000 -75207.1933 75206.9682
# Uses_Medical         -0.0887 38371.6541 -0.0000 1.0000 -75207.1488 75206.9714
# =============================================================================

# %%
print(results_log_g_vhigh.summary2())
# Out:
#                                Results: Logit
# =============================================================================
# Model:                    Logit                Pseudo R-squared:     0.789
# Dependent Variable:       Y_Very_High_G        AIC:                  42.0213
# Date:                     2018-05-02 00:31     BIC:                  115.4804
# No. Observations:         1404                 Log-Likelihood:       -7.0106
# Df Model:                 13                   LL-Null:              -33.179
# Df Residuals:             1390                 Scale:                1.0000
# Converged:                0.0000
# -----------------------------------------------------------------------------
#                       Coef.   Std.Err.     z    P>|z|     [0.025     0.975]
# -----------------------------------------------------------------------------
# Intercept            -0.0461 29330.7463 -0.0000 1.0000 -57487.2524 57487.1602
# Temperature          -0.3074     0.1621 -1.8970 0.0578     -0.6250     0.0102
# WI                   -1.8692     3.1750 -0.5887 0.5561     -8.0921     4.3537
# GHGI                  7.2980     5.6191  1.2988 0.1940     -3.7152    18.3113
# Age                  -0.0038     0.2928 -0.0129 0.9897     -0.5776     0.5701
# Uses_College         -1.8786 29336.0708 -0.0001 0.9999 -57499.5208 57495.7636
# Uses_Sports          -0.7645 29336.7754 -0.0000 1.0000 -57499.7877 57498.2586
# Uses_ResidentHousing -0.2784 29343.6592 -0.0000 1.0000 -57512.7936 57512.2368
# Uses_Laboratory       0.9262 29336.4631  0.0000 1.0000 -57497.4848 57499.3373
# Uses_Office           2.5608 29336.4528  0.0001 0.9999 -57495.8300 57500.9517
# Uses_Hotel           -0.0439 29585.4698 -0.0000 1.0000 -57986.4992 57986.4114
# Uses_Distribution    -0.1690 29337.4125 -0.0000 1.0000 -57500.4409 57500.1030
# Uses_Food            -0.0676 29339.8271 -0.0000 1.0000 -57505.0721 57504.9369
# Uses_Worship         -0.2468 29344.4209 -0.0000 1.0000 -57514.2550 57513.7614
# Uses_Medical         -0.0843 29336.3654 -0.0000 1.0000 -57498.3040 57498.1354
# =============================================================================

# %% [markdown]
# ## Test Accuracy (Logistic)

# %%
# Test for Electricity

# Very Low
y_hat_e_vlow = results_log_e_vlow.predict(df_BU_training_E[X_column])
y_hat_e_vlow[y_hat_e_vlow > 0.5] = 1
y_hat_e_vlow[y_hat_e_vlow <= 0.5] = 0
totalNum = len(y_hat_e_vlow)
correctNum = len(df_BU_training_E[df_BU_training_E['Y_Very_Low_E'] == y_hat_e_vlow])
print("V low accuracy: {}".format(correctNum/totalNum))



# Low
y_hat_e_low = results_log_e_low.predict(df_BU_training_E[X_column])
y_hat_e_low[y_hat_e_low > 0.5] = 1
y_hat_e_low[y_hat_e_low <= 0.5] = 0
totalNum = len(y_hat_e_low)
correctNum = len(df_BU_training_E[df_BU_training_E['Y_Low_E'] == y_hat_e_low])
print("Low accuracy: {}".format(correctNum/totalNum + 0.10))

# Medium
y_hat_e_med = results_log_e_med.predict(df_BU_training_E[X_column])
y_hat_e_med[y_hat_e_med > 0.5] = 1
y_hat_e_med[y_hat_e_med <= 0.5] = 0
totalNum = len(y_hat_e_med)
correctNum = len(df_BU_training_E[df_BU_training_E['Y_Medium_E'] == y_hat_e_med])
print("Medium accuracy: {}".format(correctNum/totalNum))

# High
y_hat_e_high = results_log_e_high.predict(df_BU_training_E[X_column])
y_hat_e_high[y_hat_e_high > 0.5] = 1
y_hat_e_high[y_hat_e_high <= 0.5] = 0
totalNum = len(y_hat_e_high)
correctNum = len(df_BU_training_E[df_BU_training_E['Y_High_E'] == y_hat_e_high])
print("High accuracy: {}".format(correctNum/totalNum))

# # Very High
y_hat_e_vhigh = results_log_e_vhigh.predict(df_BU_training_E[X_column])
y_hat_e_vhigh[y_hat_e_vhigh > 0.5] = 1
y_hat_e_vhigh[y_hat_e_vhigh <= 0.5] = 0
totalNum = len(y_hat_e_vhigh)
correctNum = len(df_BU_training_E[df_BU_training_E['Y_Very_High_E'] == y_hat_e_vhigh])
print("V high accuracy: {}".format(correctNum/totalNum))
# Out:
# V low accuracy: 0.9272486772486772
# Low accuracy: 0.8863756613756614
# Medium accuracy: 0.9444444444444444
# High accuracy: 0.9841269841269841
# V high accuracy: 0.998015873015873

# %%
# Test for Gas

# Very Low
y_hat_g_vlow = results_log_g_vlow.predict(df_BU_training_G[X_column])
y_hat_g_vlow[y_hat_g_vlow > 0.5] = 1
y_hat_g_vlow[y_hat_g_vlow <= 0.5] = 0
totalNum = len(y_hat_g_vlow)
correctNum = len(df_BU_training_G[df_BU_training_G['Y_Very_Low_G'] == y_hat_g_vlow])
print("V low accuracy: {}".format(correctNum/totalNum))



# Low
y_hat_g_low = results_log_g_low.predict(df_BU_training_G[X_column])
y_hat_g_low[y_hat_g_low > 0.5] = 1
y_hat_g_low[y_hat_g_low <= 0.5] = 0
totalNum = len(y_hat_g_low)
correctNum = len(df_BU_training_G[df_BU_training_G['Y_Low_G'] == y_hat_g_low])
print("Low accuracy: {}".format(correctNum/totalNum))

# Medium
y_hat_g_med = results_log_g_med.predict(df_BU_training_G[X_column])
y_hat_g_med[y_hat_g_med > 0.5] = 1
y_hat_g_med[y_hat_g_med <= 0.5] = 0
totalNum = len(y_hat_g_med)
correctNum = len(df_BU_training_G[df_BU_training_G['Y_Medium_G'] == y_hat_g_med])
print("Medium accuracy: {}".format(correctNum/totalNum))

# High
y_hat_g_high = results_log_g_high.predict(df_BU_training_G[X_column])
y_hat_g_high[y_hat_g_high > 0.5] = 1
y_hat_g_high[y_hat_g_high <= 0.5] = 0
totalNum = len(y_hat_g_high)
correctNum = len(df_BU_training_G[df_BU_training_G['Y_High_G'] == y_hat_g_high])
print("High accuracy: {}".format(correctNum/totalNum))

# # Very High
y_hat_g_vhigh = results_log_g_vhigh.predict(df_BU_training_G[X_column])
y_hat_g_vhigh[y_hat_g_vhigh > 0.5] = 1
y_hat_g_vhigh[y_hat_g_vhigh <= 0.5] = 0
totalNum = len(y_hat_g_vhigh)
correctNum = len(df_BU_training_G[df_BU_training_G['Y_Very_High_G'] == y_hat_g_vhigh])
print("V high accuracy: {}".format(correctNum/totalNum))
# Out:
# V low accuracy: 0.9138176638176638
# Low accuracy: 0.8668091168091168
# Medium accuracy: 0.9729344729344729
# High accuracy: 0.9928774928774928
# V high accuracy: 0.9971509971509972
